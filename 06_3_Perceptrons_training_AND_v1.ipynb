# %% [markdown]
# ### Perceptrons - Training

# %% [markdown]
# Note for 717005@ Hallym University !

# %% [markdown]
# * Make a prediction with weights

# %%
def predict(X, w):
    bias = w[0]
    activation = bias + w[1]* X[0] + w[2]* X[1]
    if activation >= 0.0:
        return 1.0
    else:
        return 0.0

# %% [markdown]
# * Estimate Perceptron weights using stochastic gradient descent

# %%
def train_weights(train, l_rate, n_epoch):
    #weights = [0.0 for i in range(len(train[0]))]
    weights = [0,0,0]
    print(weights)
    print('----------------------------')
    
    vb=[]
    vw0=[]
    vw1=[]
    
    for epoch in range(n_epoch):
        sum_error = 0.0
        for row in train: # 데이터에서 한줄씩 꺼내서 씀
            prediction = predict(row, weights)
            corr = row[-1]
            error = corr - prediction
            sum_error += error**2
            
            weights[0] = weights[0] + l_rate * error # bias
            for i in range(len(row)-1):
                weights[i + 1] = weights[i + 1] + l_rate * error * row[i] # weights
                
            vb.append(weights[0])
            vw0.append(weights[1])
            vw1.append(weights[2])
            
        print('epoch={}, error={}'.format(epoch, sum_error))
    return weights, vb, vw0, vw1

# %%
# training set for AND gate
dataset = [[0,0,0],
    [1,0,0],
    [0,1,0],
    [1,1,1]]

# %% [markdown]
# * Hyperparameters
#
# 하이퍼파라미터
#
# 사람이 정해주는

# %%
l_rate = 0.1
n_epoch = 5

# %%
weights, vb, vw0, vw1 = train_weights(dataset, l_rate, n_epoch)
# Out:
# [0, 0, 0]
# ----------------------------
# epoch=0, error=2.0
# epoch=1, error=3.0
# epoch=2, error=3.0
# epoch=3, error=0.0
# epoch=4, error=0.0

# %%
print(weights) # w 0.2를 찾음을 프린트
# Out:
# [-0.20000000000000004, 0.1, 0.2]

# %%
prediction = predict([0,0], weights)
print(prediction)
# Out:
# 0.0

# %%
prediction = predict([0,1], weights)
print(prediction)
# Out:
# 0.0

# %%
prediction = predict([1,0], weights)
print(prediction)
# Out:
# 0.0

# %%
prediction = predict([0.5,1], weights)
print(prediction)
# Out:
# 1.0

# %%
prediction = predict([0.9,1], weights)
print(prediction)
# Out:
# 1.0

# %%
prediction = predict([0.00001,1], weights)
print(prediction)
# Out:
# 1.0

# %%
prediction = predict([1,0.500001], weights)
print(prediction)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(vb)
plt.plot(vw0)
plt.plot(vw1)

# %% [markdown]
# * Why ?

# %% [markdown]
# partial derivative with respect to m

# %% [markdown]
# $$ \frac{\partial J(m,b)}{\partial m} =  \frac{1}{n}\sum_{i=1}^{n} -2 x^{(i)} (y_{i}-(mx^{(i)} + b)) \\
# = \frac{2}{n}\sum_{i=1}^{n} x^{(i)} ((mx^{(i)} + b)-y^{(i)}) \\
# = \frac{2}{n}\sum_{i=1}^{n} x^{(i)} (\hat{y}^{(i)} -y^{(i)})$$

# %% [markdown]
# //m으로 미분했을때 x가 남음

# %% [markdown]
# partial derivative with respect to b

# %% [markdown]
# $$ \frac{\partial J(m,b)}{\partial b} =  \frac{1}{n}\sum_{i=1}^{n} -2  (y^{(i)}-(mx^{(i)} + b)) \\
# = \frac{-2}{n}\sum_{i=1}^{n}  (y^{(i)}-(mx^{(i)} + b)) \\
# = \frac{2}{n}\sum_{i=1}^{n}  (\hat{y}^{(i)}-y^{(i)}) \\ $$

# %% [markdown]
# //반면 b로 미분했을땐 b 부분이 1이되어 다른부분은 전부 사라짐

# %% [markdown]
# Partial derivatives : https://www.mathsisfun.com/calculus/derivatives-partial.html

# %% [markdown]
# * References

# %% [markdown]
# ```
# https://machinelearningmastery.com/implement-perceptron-algorithm-scratch-python/
# ```
